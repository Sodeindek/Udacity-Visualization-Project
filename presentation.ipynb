# %% [markdown]
# # Part II - (Ford bikes project)
# ## by (Sodeinde Kehinde Ikeoluwa)

# %% [markdown]
# ## Investigation Overview
#
#
# This is a project in the ALX nanodegree program. Basically, the project is to practice data visualization and apply it to exploratory data analysis.
# Based on the visualization exploratory analysis carried out, the following were discovered;
# ## Dataset Overview
# Ford GoBike System Data: This dataset includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.
# The following are rows/parameters present in the dataset.
# The average ride duration(secs) and median ride duration(secs) for the users is approximately 704 secs and 510 secs respectively
# - There seem to be an uptrend in the number of riders starting out as the day goes by , but peak hours are 8 in the morning and 5 at night.
# - Average rider's age is 36 years old
# - Majority of the users are male, surmounting to approximately 75% of the total population
# - Weekends are less busier than the rest of the week days
# - Only a few users are participans of the bike share program
# - Averagely, customers tends to spend more time riding compare to subscribers.
# - This is quite surprising, Other and Female ride longer than male on an average.
# - Male has an higher population using the services all week long, this is not suprising as they make up 75% of the entire users.
#
# ## Dataset Overview
# Ford GoBike System Data: This dataset includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.
# The following are rows/parameters present in the dataset.

# %%
# import all packages and set plots to be embedded inline
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import calendar
import math
import time

# %matplotlib inline

# %%
#importing the dataset and looking through its structure

df = pd.read_csv(r"C:\Users\HP\Desktop\Python\Ford GoBike\ford Gobike.csv")
df.head()
# Out:
#    Unnamed: 0  duration_sec               start_time  start_hour start_day  \
# 0           0         52185  2019-02-28 17:32:10.145          17  Thursday
# 1           2         61854  2019-02-28 12:13:13.218          12  Thursday
# 2           3         36490  2019-02-28 17:54:26.010          17  Thursday
# 3           4          1585  2019-02-28 23:54:18.549          23  Thursday
# 4           5          1793  2019-02-28 23:49:58.632          23  Thursday
#
#   start_month                 end_time  end_hour end_day end_month  ...  \
# 0    February  2019-03-01 08:01:55.975         8  Friday     March  ...
# 1    February  2019-03-01 05:24:08.146         5  Friday     March  ...
# 2    February  2019-03-01 04:02:36.842         4  Friday     March  ...
# 3    February  2019-03-01 00:20:44.074         0  Friday     March  ...
# 4    February  2019-03-01 00:19:51.760         0  Friday     March  ...
#
#    end_station_id                              end_station_name  \
# ...

# %% [markdown]
# ## Visualisation 1
# ## User Gender Distribution
#
# This is a univariate exploration, it shows the distribution of start hours of riders. Weekends are less busier than the rest of the week days

# %%
def mycounting(df,xVar, hue=None, color=0, palette=None,order=None, hue_order=None) :
    ''' This me practicing out looping to avoid repetitive codes'''
    #set plot dimension
    plt.figure(figsize=[14,7])
    #plotting
    sb.countplot(data=df,x=xVar, hue=hue,color=sb.color_palette()[color],palette=palette,order= order,edgecolor='black',hue_order=hue_order,linewidth=2);
    # title and labels
    xVar= xVar.replace('_',' ')
    if hue: 
        hue=hue.replace('_',' ')
    #Adding title
    plt.title(f'''Distribution of {xVar} {'by' if hue else ''} {hue if hue else''}'''.title(), fontsize =14, weight ='bold')
    plt.xlabel(xVar.title(), fontsize=10, weight='bold')
    plt.ylabel('Frequency'.title(), fontsize=10, weight='bold')
    
    #plot start hour
mycounting(df,'start_hour')

# %% [markdown]
# ## Visualisation 2
# ## Reltionship between user type and trip duration
#
# The following visualisation is a bivariate exploration, it shows the distribution of the various user type and its relationship with trip duration in minutes.

# %%
sb.catplot(x='user_type', y='duration_min', data=df, kind='bar', ci=None, edgecolor='black')
plt.title('Average Duration(min) by User type',fontsize=15)
plt.ylabel('Duration(min)',fontsize=13)
plt.xlabel('User Type',fontsize=13)
# Out:
# Text(0.5, 6.79999999999999, 'User Type')

# %% [markdown]
# ## Visualisation 3
# ## Correllation between all parameters
#
# This third visualisation is a multivariate, it displays the correllation that exists between specific numerical parameters in the dataset.

# %%
data_stat = ['age_diff', 'duration_min',"duration_sec", "member_birth_year"]
plt.figure(figsize = (12,5), dpi = 200)

sb.heatmap(df[data_stat].corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
plt.title(" What is the  Correlation between each variable in the dataset?", y=1.09, fontsize=15, weight='bold');

# %%
# !jupyter nbconvert presentation.ipynb --to slides --post serve  --no-input --no-prompt
